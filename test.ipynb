# %%
import pdfplumber

with pdfplumber.open("src/data/49156.pdf") as pdf:
    first_page = pdf.pages[0]
    text = first_page.extract_text()
    print(text)
# Out:
# PD PRELADA
# Tel.: 226198120
# Pingo Doce - Distribuição Alimentar, S.A.
# Sede: R Actor António Silva,N7,1649-033 Lisboa
# Registo C.R.C. Lisboa-Matrícula/NIPC: 500829993
# C. Social: 33.808.115 EUR / Registo Produtor:
# PT001730, PT01101095, PT03000085,
# PT06000383, PT04000029
# Artigos
# MERCEARIA + PET FOOD
# E DIGES MAÇA 171G 2,49
# Poupança Imediata (0,50)
# PRONTO A COMER
# E PIZZA FRES PD CA415G 2,89
# Resumo
# TOTAL 5,38
# TOTAL POUPANÇA (0,50)
# TOTAL A PAGAR 4,88
# Pagamentos
# TOTAL PAGO 4,88
# Multibanco 4,88
# Resumo IVA
# Taxa Valor s/IVA Valor IVA Valor c/IVA
# E 23% 3,97 0,91 4,88
# ------------------------------------------------
# NESTA COMPRA POUPOU
# 0,50 €
# -----------------------------------------------
# Cartão nº: ***************035
# Combustível ganho na compra: 0 EUR
# Saldo disponível: 8 EUR
# Expiram a 31-8-2025: 8 EUR
# 049155 2025-08-28 17:49 0795 0095 0489
# ------------------------------------------------
# PINGO DOCE PRELADA
# PRELADA
# PORTO
# ...

# %%
import pdfplumber

with pdfplumber.open("src/data/56645.pdf") as pdf:
    first_page = pdf.pages[0]
    text = first_page.extract_text()
    print(text)
# Out:
# PD PRELADA
# Tel.: 226198120
# Pingo Doce - Distribuição Alimentar, S.A.
# Sede: R Actor António Silva,N7,1649-033 Lisboa
# Registo C.R.C. Lisboa-Matrícula/NIPC: 500829993
# C. Social: 33.808.115 EUR / Registo Produtor:
# PT001730, PT01101095, PT03000085,
# PT06000383, PT04000029
# Artigos
# PEIXARIA
# C TRANCHE SALMÃO UN150 2,000 X 3,69 7,38
# Poupança Imediata (3,40)
# Exclusivo POUPA Shaker (0,40)
# PADARIA/PASTELARIA
# E PÃO DE LEITE 1,99
# E BOLA BERLIM KIT KAT 1,000 X 0,99 0,99
# E BOLA BERLIM SIMPLES 1,000 X 0,79 0,79
# E MERENDA MISTA 95 G 2,000 X 0,79 1,58
# FRUTAS E VEGETAIS
# C BANANA IMPORTADA 0,645 X 1,25 0,81
# Poupança Imediata (0,04)
# CONGELADOS
# C ALM TOMA S/GL PD420G 4,29
# C BROCOLOS PD 400G 2 X 0,89 1,78
# Resumo
# TOTAL 19,61
# TOTAL POUPANÇA (3,84)
# TOTAL A PAGAR 15,77
# Pagamentos
# TOTAL PAGO 15,77
# Multibanco 15,77
# Resumo IVA
# Taxa Valor s/IVA Valor IVA Valor c/IVA
# C 6% 9,83 0,59 10,42
# E 23% 4,35 1,00 5,35
# ...
